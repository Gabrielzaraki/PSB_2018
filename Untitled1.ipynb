# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.hanning(100)
b = np.blackman(100)
c = np.hamming(100)
d = np.bartlett(100)

# %%
plt.plot(a,'r',b,'b',c,'g',d,'x')

# %%
z = np.array(np.blackman(10))

# %%
z = z.T

# %%
plt.plot(z)

# %%
A = np.blackman(5)
A
# Out:
# array([-1.38777878e-17,  3.40000000e-01,  1.00000000e+00,  3.40000000e-01,
#        -1.38777878e-17])

# %%
B = np.full((4,4), np.hamming(4))
B
# Out:
# array([[0.08, 0.77, 0.77, 0.08],
#        [0.08, 0.77, 0.77, 0.08],
#        [0.08, 0.77, 0.77, 0.08],
#        [0.08, 0.77, 0.77, 0.08]])
